# %% [markdown]
# # Overlap Graphs
#
#
# A graph whose nodes have all been labeled can be represented by an adjacency list, in which each row of the list contains the two node labels corresponding to a unique edge.
#
# A directed graph (or digraph) is a graph containing directed edges, each of which has an orientation. That is, a directed edge is represented by an arrow instead of a line segment; the starting and ending nodes of an edge form its tail and head, respectively. The directed edge with tail v and head w is represented by (v,w) (but not by (w,v)). A directed loop is a directed edge of the form (v,v).
#
# For a collection of strings and a positive integer k, the overlap graph for the strings is a directed graph Ok in which each string is represented by a node, and string s is connected to string t with a directed edge when there is a length k suffix of s that matches a length k prefix of t, as long as s≠t; we demand s≠t to prevent directed loops in the overlap graph (although directed cycles may be present).
#
# - Given: A collection of DNA strings in FASTA format having total length at most 10 kbp.
# - Return: The adjacency list corresponding to O3. You may return edges in any order.
#
# > **Sample Dataset**
# >
# ```
# >Rosalind_0498
# AAATAAA
# >Rosalind_2391
# AAATTTT
# >Rosalind_2323
# TTTTCCC
# >Rosalind_0442
# AAATCCC
# >Rosalind_5013
# GGGTGGG
# ```
#
# > **Sample Output**
# >
# ```
# Rosalind_0498 Rosalind_2391
# Rosalind_0498 Rosalind_0442
# Rosalind_2391 Rosalind_2323
# ```

# %%
def parseFasta(file):
    with open(file, 'r') as f:
        content = "".join(line.rstrip() for line in f).split(">")[1:]

    idList = [content[i][:13] for i in range(len(content))]
    seqList = [content[i][13:] for i in range(len(content))]
    
    return(idList, seqList)

# %%
def olapGraphs(idList, seqList, k = 3):
    
    lookUp = dict(zip(seqList, idList))
    
    import itertools
    for pair in itertools.combinations(seqList, 2):
        
        if pair[0][-k:] == pair[1][:k]:
            print(lookUp[pair[0]], lookUp[pair[1]])
            
        if pair[1][-k:] == pair[0][:k]: #don't forget the other direction!!
            print(lookUp[pair[1]], lookUp[pair[0]])

# %%
idList, seqList = parseFasta("Q12.txt")
olapGraphs(idList, seqList)
# Out:
# Rosalind_0498 Rosalind_2391
# Rosalind_0498 Rosalind_0442
# Rosalind_2391 Rosalind_2323

# %%
idList, seqList = parseFasta("rosalind_grph.txt")
olapGraphs(idList, seqList, 3)
# Out:
# Rosalind_0293 Rosalind_3848
# Rosalind_5288 Rosalind_3848
# Rosalind_9287 Rosalind_3848
# Rosalind_0218 Rosalind_3996
# Rosalind_0908 Rosalind_0218
# Rosalind_2634 Rosalind_3996
# Rosalind_1719 Rosalind_2634
# Rosalind_0807 Rosalind_8324
# Rosalind_7820 Rosalind_1110
# Rosalind_0987 Rosalind_7820
# Rosalind_3256 Rosalind_4010
# Rosalind_3256 Rosalind_1236
# Rosalind_9837 Rosalind_9973
# Rosalind_6807 Rosalind_9973
# Rosalind_1236 Rosalind_9973
# Rosalind_1089 Rosalind_9973
# Rosalind_3595 Rosalind_9973
# Rosalind_9837 Rosalind_1366
# Rosalind_2523 Rosalind_9837
# Rosalind_4520 Rosalind_9814
# Rosalind_4520 Rosalind_1849
# Rosalind_1849 Rosalind_4520
# Rosalind_8655 Rosalind_5388
# Rosalind_5388 Rosalind_9365
# Rosalind_3484 Rosalind_3263
# Rosalind_3484 Rosalind_0807
# Rosalind_6884 Rosalind_4181
# Rosalind_0987 Rosalind_4944
# Rosalind_4944 Rosalind_1570
# Rosalind_0447 Rosalind_1743
# Rosalind_3192 Rosalind_3692
# Rosalind_3192 Rosalind_3392
# Rosalind_7830 Rosalind_3192
# Rosalind_0526 Rosalind_3192
# Rosalind_7917 Rosalind_3192
# Rosalind_3996 Rosalind_4853
# Rosalind_3996 Rosalind_3013
# Rosalind_3996 Rosalind_4003
# Rosalind_7328 Rosalind_0293
# Rosalind_0293 Rosalind_6855
# Rosalind_0293 Rosalind_1335
# Rosalind_0293 Rosalind_0864
# Rosalind_0293 Rosalind_8309
# Rosalind_1743 Rosalind_3118
# Rosalind_3118 Rosalind_9814
# Rosalind_3118 Rosalind_1849
# Rosalind_0550 Rosalind_1743
# Rosalind_9994 Rosalind_0550
# Rosalind_1640 Rosalind_0550
# Rosalind_0864 Rosalind_0550
# Rosalind_0987 Rosalind_6884
# Rosalind_6884 Rosalind_9277
# Rosalind_5506 Rosalind_1719
# Rosalind_5288 Rosalind_6855
# Rosalind_9277 Rosalind_5288
# Rosalind_8046 Rosalind_5288
# Rosalind_5288 Rosalind_1335
# Rosalind_5288 Rosalind_0864
# Rosalind_5288 Rosalind_8309
# Rosalind_4853 Rosalind_3692
# Rosalind_3692 Rosalind_8648
# Rosalind_5693 Rosalind_3692
# Rosalind_3692 Rosalind_1089
# Rosalind_6318 Rosalind_3692
# Rosalind_1110 Rosalind_1743
# Rosalind_4853 Rosalind_3392
# Rosalind_9287 Rosalind_6855
# Rosalind_4266 Rosalind_9287
# Rosalind_9287 Rosalind_1335
# Rosalind_9287 Rosalind_0864
# Rosalind_9287 Rosalind_8309
# Rosalind_8711 Rosalind_2523
# Rosalind_8711 Rosalind_9824
# Rosalind_4010 Rosalind_8046
# Rosalind_8348 Rosalind_4010
# Rosalind_4010 Rosalind_6616
# Rosalind_5589 Rosalind_4010
# Rosalind_1475 Rosalind_0987
# Rosalind_0987 Rosalind_3595
# Rosalind_9824 Rosalind_0987
# Rosalind_6807 Rosalind_1366
# Rosalind_1366 Rosalind_1331
# Rosalind_1236 Rosalind_1366
# Rosalind_1366 Rosalind_3610
# Rosalind_1366 Rosalind_0908
# Rosalind_1366 Rosalind_3861
# Rosalind_1089 Rosalind_1366
# Rosalind_3595 Rosalind_1366
# Rosalind_5693 Rosalind_3392
# Rosalind_6318 Rosalind_3392
# Rosalind_2705 Rosalind_6807
# Rosalind_5506 Rosalind_7830
# Rosalind_7830 Rosalind_5693
# Rosalind_7495 Rosalind_3709
# Rosalind_3709 Rosalind_9814
# Rosalind_3709 Rosalind_1849
# Rosalind_7495 Rosalind_9006
# Rosalind_2705 Rosalind_7495
# Rosalind_3013 Rosalind_0688
# Rosalind_7101 Rosalind_2523
# Rosalind_2523 Rosalind_5394
# Rosalind_4003 Rosalind_2523
# Rosalind_0526 Rosalind_5693
# Rosalind_1475 Rosalind_0526
# Rosalind_9824 Rosalind_0526
# Rosalind_6855 Rosalind_9814
# Rosalind_6855 Rosalind_1849
# Rosalind_1331 Rosalind_7101
# Rosalind_9277 Rosalind_6584
# Rosalind_1743 Rosalind_9651
# Rosalind_1743 Rosalind_2705
# Rosalind_8309 Rosalind_1743
# Rosalind_1743 Rosalind_6949
# Rosalind_4266 Rosalind_5506
# Rosalind_0908 Rosalind_4266
# Rosalind_1982 Rosalind_9814
# Rosalind_6584 Rosalind_9814
# Rosalind_9365 Rosalind_9814
# Rosalind_0688 Rosalind_7101
# Rosalind_7101 Rosalind_9824
# Rosalind_3610 Rosalind_1982
# Rosalind_1982 Rosalind_1849
# Rosalind_9006 Rosalind_7917
# Rosalind_8046 Rosalind_6584
# Rosalind_8348 Rosalind_1236
# Rosalind_5589 Rosalind_1236
# Rosalind_9651 Rosalind_0688
# Rosalind_5357 Rosalind_9191
# Rosalind_1335 Rosalind_1570
# Rosalind_6949 Rosalind_3778
# Rosalind_4003 Rosalind_9824
# Rosalind_6584 Rosalind_1849
# Rosalind_3861 Rosalind_9191
# Rosalind_8655 Rosalind_8348
# Rosalind_9365 Rosalind_1849
# Rosalind_4099 Rosalind_1640
# Rosalind_9326 Rosalind_6318
# Rosalind_9326 Rosalind_8655
# Rosalind_0807 Rosalind_9326
# Rosalind_5812 Rosalind_8648
# Rosalind_2216 Rosalind_8648
# Rosalind_8648 Rosalind_9365
# Rosalind_2142 Rosalind_5812
# Rosalind_7917 Rosalind_5693
# Rosalind_8655 Rosalind_1475
# Rosalind_5812 Rosalind_1089
# Rosalind_9191 Rosalind_5812
# Rosalind_2216 Rosalind_1089
# Rosalind_6616 Rosalind_6318
# Rosalind_1570 Rosalind_5377
# Rosalind_1261 Rosalind_5377
# Rosalind_6616 Rosalind_8655
# Rosalind_0807 Rosalind_5383
